# %% [markdown]
# <a href="https://colab.research.google.com/github/dakshitabhandari/Psets/blob/main/venkatesh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
C:\Users\SwapnilSir\Downloads\Graffiti Elite.xlsx

# %%
import pandas as pd

# %%
d=pd.read_excel(r"C:\Users\SwapnilSir\Downloads\Graffiti Elite.xlsx")

# %%
d
# Out:
#     SRNO                    Projnm                    Bldg   Unitno  \
# 0      1  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -106
# 1      2  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -805
# 2      3  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -506
# 3      4  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -504
# 4      5  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -903
# 5      6  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -305
# 6      7  Venkatesh Graffiti Elite  Phase 1 - "A" Building  A -1402
# 7      8  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -902
# 8      9  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -703
# 9     10  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -704
# 10    11  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -702
# 11    12  Venkatesh Graffiti Elite  Phase 1 - "A" Building  A -1305
# 12    13  Venkatesh Graffiti Elite  Phase 1 - "A" Building   A -705
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 15 columns):
# SRNO                44 non-null int64
# Projnm              44 non-null object
# Bldg                44 non-null object
# Unitno              44 non-null object
# customer_name       44 non-null object
# Co_Applicant1       23 non-null object
# Co_Applicant2       0 non-null float64
# Co_Applicant3       0 non-null float64
# Mobile              44 non-null int64
# email               39 non-null object
# Customer_Address    43 non-null object
# Designation         26 non-null object
# Birth_date          33 non-null datetime64[ns]
# Anni_date           23 non-null datetime64[ns]
# Occupation          34 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(9)
# memory usage: 5.2+ KB

# %%
df=pd.DataFrame(d,columns=['Customer_Address'])

# %%
print(df)
# Out:
#                                      Customer_Address
# 0                                              BARSHI
# 1              E-708, Venkatesh Graffiti, Keshavnagar
# 2           E 506 VENKATESH GRAFFITI KESHAVNAGAR PUNE
# 3   VENKATESH GRAFFITI, FLAT NO - F/404, KESHAVNAG...
# 4   E-1001, VENKATESH GRAFFITI, KESHAVNAGAR MUNDHW...
# 5   AMBIKA NAGAR, INFRONT OF TELEHONE EXCHANGE OFF...
# 6   C1-303, CELEBREIA, PUNE-SOLAPUR ROAD, HADAPSAR...
# 7   Venkatesh Graffiti Flat No C 404 Manjri Road P...
# 8   207 SAHAKAR NAGAR NEAR GAJANAND MAHARAJ MANDIR...
# 9   B1-603, Saarthi Shilp, behind Eklavya colledge...
# 10  A-805, Venkatesh Graffiti, Keshawnagar, Pune -...
# 11  D2 / 75, SHANTIRAKSHAK SOCIETY, YERWADA, PUNE ...
# 12  D/O PRALHAD 115/24 BONGATE BUNGLOW MURARJI PET...
# 13  FLAT NO. C-705, VENKATESH GRAFFITI, MUNDHWA MA...
# 14  A 202  Dhayari,Venkatesh Bilva, Dhayari, Vijay...
# 15  59/A Ghorpadi village opp Basant raj Society P...
# ...

# %%
for i in df:
    for r in i:
        print(i)
# Out:
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address
# Customer_Address

# %%
df.dtypes
# Out:
# Customer_Address    object
# dtype: object

# %%
df.tail()
# Out:
#                                      Customer_Address
# 39                                      VADGAON SHERI
# 40  14,VERMA LAYOUT NEAR NORTH AMBAZARI ROAD, NAGP...
# 41                       HANDEWADI ROAD,HADAPSAR,PUNE
# 42                                                  _
# 43                                                  _

# %%
df.head(1)
# Out:
#   Customer_Address
# 0           BARSHI

# %%
df
# Out:
#                                      Customer_Address
# 0                                              BARSHI
# 1              E-708, Venkatesh Graffiti, Keshavnagar
# 2           E 506 VENKATESH GRAFFITI KESHAVNAGAR PUNE
# 3   VENKATESH GRAFFITI, FLAT NO - F/404, KESHAVNAG...
# 4   E-1001, VENKATESH GRAFFITI, KESHAVNAGAR MUNDHW...
# 5   AMBIKA NAGAR, INFRONT OF TELEHONE EXCHANGE OFF...
# 6   C1-303, CELEBREIA, PUNE-SOLAPUR ROAD, HADAPSAR...
# 7   Venkatesh Graffiti Flat No C 404 Manjri Road P...
# 8   207 SAHAKAR NAGAR NEAR GAJANAND MAHARAJ MANDIR...
# 9   B1-603, Saarthi Shilp, behind Eklavya colledge...
# 10  A-805, Venkatesh Graffiti, Keshawnagar, Pune -...
# 11  D2 / 75, SHANTIRAKSHAK SOCIETY, YERWADA, PUNE ...
# 12  D/O PRALHAD 115/24 BONGATE BUNGLOW MURARJI PET...
# 13  FLAT NO. C-705, VENKATESH GRAFFITI, MUNDHWA MA...
# 14  A 202  Dhayari,Venkatesh Bilva, Dhayari, Vijay...
# 15  59/A Ghorpadi village opp Basant raj Society P...
# ...

# %%
df.fillna('0',inplace=True)

# %%
df
# Out:
#                                      Customer_Address
# 0                                              BARSHI
# 1              E-708, Venkatesh Graffiti, Keshavnagar
# 2           E 506 VENKATESH GRAFFITI KESHAVNAGAR PUNE
# 3   VENKATESH GRAFFITI, FLAT NO - F/404, KESHAVNAG...
# 4   E-1001, VENKATESH GRAFFITI, KESHAVNAGAR MUNDHW...
# 5   AMBIKA NAGAR, INFRONT OF TELEHONE EXCHANGE OFF...
# 6   C1-303, CELEBREIA, PUNE-SOLAPUR ROAD, HADAPSAR...
# 7   Venkatesh Graffiti Flat No C 404 Manjri Road P...
# 8   207 SAHAKAR NAGAR NEAR GAJANAND MAHARAJ MANDIR...
# 9   B1-603, Saarthi Shilp, behind Eklavya colledge...
# 10  A-805, Venkatesh Graffiti, Keshawnagar, Pune -...
# 11  D2 / 75, SHANTIRAKSHAK SOCIETY, YERWADA, PUNE ...
# 12  D/O PRALHAD 115/24 BONGATE BUNGLOW MURARJI PET...
# 13  FLAT NO. C-705, VENKATESH GRAFFITI, MUNDHWA MA...
# 14  A 202  Dhayari,Venkatesh Bilva, Dhayari, Vijay...
# 15  59/A Ghorpadi village opp Basant raj Society P...
# ...

# %%
df.drop(['42,43'],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fd30bf49bf15> in <module>
# ----> 1 df.drop(['42,43'],axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.head(3)

# %%
import numpy as np
a = np.array([[0, 1], [2, 3]], order='C')

a.resize((2, 2))
print(a)
# Out:
# [[0 1]
#  [2 3]]

# %%
import numpy as np
df = np.array(df[1:], dtype=np.object)

# %%
df
# Out:
# array([['E-708, Venkatesh Graffiti, Keshavnagar'],
#        ['E 506 VENKATESH GRAFFITI KESHAVNAGAR PUNE'],
#        ['VENKATESH GRAFFITI, FLAT NO - F/404, KESHAVNAGAR PUNE'],
#        ['E-1001, VENKATESH GRAFFITI, KESHAVNAGAR MUNDHWA, PUNE'],
#        ['AMBIKA NAGAR, INFRONT OF TELEHONE EXCHANGE OFFICE, INDAPUR, DIST - PUNE - 413106'],
#        ['C1-303, CELEBREIA, PUNE-SOLAPUR ROAD, HADAPSAR, PUNE 411 028'],
#        ['Venkatesh Graffiti Flat No C 404 Manjri Road Pune 411036'],
#        ['207 SAHAKAR NAGAR NEAR GAJANAND MAHARAJ MANDIR KHAMLA ROAD NAGPUR 44002'],
#        ['B1-603, Saarthi Shilp, behind Eklavya colledge, kothrud, Pune 411 038'],
#        ['A-805, Venkatesh Graffiti, Keshawnagar, Pune - 411036'],
#        ['D2 / 75, SHANTIRAKSHAK SOCIETY, YERWADA, PUNE - 411006'],
#        ['D/O PRALHAD 115/24 BONGATE BUNGLOW MURARJI PETH MULAY HOSPITAL SOLAPUR'],
#        ['FLAT NO. C-705, VENKATESH GRAFFITI, MUNDHWA MANJARI ROAD, KESHAV NAGAR, PUNE 411036'],
# ...

# %%
df[5,:]
# Out:
# array(['C1-303, CELEBREIA, PUNE-SOLAPUR ROAD, HADAPSAR, PUNE 411 028'],
#       dtype=object)

# %%
df[:,0]
# Out:
# array(['E-708, Venkatesh Graffiti, Keshavnagar',
#        'E 506 VENKATESH GRAFFITI KESHAVNAGAR PUNE',
#        'VENKATESH GRAFFITI, FLAT NO - F/404, KESHAVNAGAR PUNE',
#        'E-1001, VENKATESH GRAFFITI, KESHAVNAGAR MUNDHWA, PUNE',
#        'AMBIKA NAGAR, INFRONT OF TELEHONE EXCHANGE OFFICE, INDAPUR, DIST - PUNE - 413106',
#        'C1-303, CELEBREIA, PUNE-SOLAPUR ROAD, HADAPSAR, PUNE 411 028',
#        'Venkatesh Graffiti Flat No C 404 Manjri Road Pune 411036',
#        '207 SAHAKAR NAGAR NEAR GAJANAND MAHARAJ MANDIR KHAMLA ROAD NAGPUR 44002',
#        'B1-603, Saarthi Shilp, behind Eklavya colledge, kothrud, Pune 411 038',
#        'A-805, Venkatesh Graffiti, Keshawnagar, Pune - 411036',
#        'D2 / 75, SHANTIRAKSHAK SOCIETY, YERWADA, PUNE - 411006',
#        'D/O PRALHAD 115/24 BONGATE BUNGLOW MURARJI PETH MULAY HOSPITAL SOLAPUR',
#        'FLAT NO. C-705, VENKATESH GRAFFITI, MUNDHWA MANJARI ROAD, KESHAV NAGAR, PUNE 411036',
# ...

# %%
# !pip install geopy

# %%
import pandas as pd
import os
from geopy import geocoders
from geopy.geocoders import GoogleV3

API_KEY = os.getenv("API1234")
g = GoogleV3(api_key=API_KEY)



loc_address = [pune]
for address in df.Address:
    try:
        inputAddress = pune
        location = g.geocode(inputAddress, timeout=15)
        loc_coordinates.append((location.latitude, location.longitude))
        loc_address.append(inputAddress)
    except Exception as e:
        print('Error, skipping address...', e)


df_geocodes = pd.DataFrame({'coordinate':loc_coordinates,'address':loc_address})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Since July 2018 Google requires each request to have an API key. Pass a valid `api_key` to GoogleV3 geocoder to hide this warning. See https://developers.google.com/maps/documentation/geocoding/usage-and-billing
#   import sys
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-df147f2bab5f> in <module>
#       9
#      10
# ---> 11 loc_address = [pune]
#      12 for address in df.Address:
#      13     try:
#
# NameError: name 'pune' is not defined
